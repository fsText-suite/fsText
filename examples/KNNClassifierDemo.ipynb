# %% [markdown]
# # K-NN Classifier - Example

# %%
from fsText.Classifier import KNNClassifier
import pandas as pd
import numpy as np
# Out:
# /anaconda3/lib/python3.6/site-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.21.1) or chardet (2.3.0) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
clf = KNNClassifier()
# Out:
# Loading pre-trained Word2Vec model...

# %%
df = pd.read_csv('examples/datasets/stack.csv')

def gen_sample(sample_size, num_classes):
    
    df_1 = df[(df["Label"]<num_classes + 1)].reset_index().drop(["index"], axis=1).reset_index().drop(["index"], axis=1)
    train = df_1[df_1["Label"] == np.unique(df_1['Label'])[0]].sample(sample_size)
    
    train_index = train.index.tolist()
    
    for i in range(1,num_classes):
        train_2 = df_1[df_1["Label"] == np.unique(df_1['Label'])[i]].sample(sample_size)
        train = pd.concat([train, train_2], axis=0)
        train_index.extend(train_2.index.tolist())
        
    test = df_1[~df_1.index.isin(train_index)]

    return train, test

# %%
train, test = gen_sample(15,4)
train
# Out:
#                                                    Text  Label
# 3958          WP_Insert_Post and GUID Issue [Wordpress]      1
# 2540                  How can I debug WordPress in IIS?      1
# 3594  wordpress: how to get x youtube thumbnails of ...      1
# 3240  Where to place a query to show only one post i...      1
# 3638                   Wordpress Blog RSS Feed Problems      1
# 3702                Excluding one category in Wordpress      1
# 1720   debuging "register_activation_hook" in wordpress      1
# 3622               Wordpress "Read more" is not working      1
# 3895                 Create blog post simply and easily      1
# 3727            Why is IE7 rendering these differently?      1
# 3900                 Using AJAX to load WordPress pages      1
# 3310                  WordPress Monthly Archive by Year      1
# 3521  Is there an easier way to add menu items to a ...      1
# 538   Wordpress: How can i move my index (blogpage) ...      1
# 3286  wp_list_categories does not show current category      1
# 388   What is the default URL for APEX for an Oracle...      2
# 2147    Oracle DB: How can I write query ignoring case?      2
# 1332  Oracle converts empty string to null but JPA d...      2
# 575   Is there a way to do full text search of all o...      2
# 1943  Faster 'select distinct thing_id,thing_name fr...      2
# 1564  When did oracle start supporting "top": select...      2
# 2063  Return an Oracle Ref Cursor to a SqlServer T-S...      2
# 2541  How do I insert sysdate into a column using OD...      2
# 981   Is it possible to kill a single query in oracl...      2
# 2282  Calculate difference between 2 date / times in...      2
# 404                                         Oracle date      2
# 2218  Compare strings by their written representatio...      2
# 1081  Allow Oracle User to connect from one IP addre...      2
# 2346  What's the equivalent of Oracle's to_char in A...      2
# 871   Oracle: how to use updateXML to update multipl...      2
# 338                 subversion diff including new files      3
# 663   Unlocking a SVN working copy which has unversi...      3
# 898                 Windows Backup for SVN Repositories      3
# 2376  Using svn:ignore to ignore everything but cert...      3
# 1323  How can I only commit property changes without...      3
# 2098  How to forbit subversion commits to svn:extern...      3
# 136                     How can I speed up SVN updates?      3
# 57                                         Begining SVN      3
# 1013       Is there any way to only update added files?      3
# 1137  Change Revesion Number in Subversion, even if ...      3
# 2027                             svn create tag problem      3
# 708   Is there some way to commit a file "partially"...      3
# 124                        Free Online SVN repositories      3
# 302   Create a tag upon every build of the application?      3
# 958                 Subversion plugin to Visual Studio?      3
# 3200  How to view error messages from ruby CGI app o...      4
# 2822                          PHP using too much memory      4
# 1831  Getting Apache to execute command on every pag...      4
# 2901    XAMPP: I edited PHP.ini, and now Apache crashes      4
# 195   Restrict Apache to only allow access using SSL...      4
# 3623  Adding slashes to the end of directories + mor...      4
# 689             IIS equivalent of VirtualHost in Apache      4
# 2272  Why do some page requests hang when fetching i...      4
# 1361                         Setting a header in apache      4
# 1874                   Apache Perl http headers problem      4
# 3444                       .htaccess mod-rewrite how to      4
# 2684      Problem with URL rewriting for same .php page      4
# 299   Top & httpd - demystifying what is actually ru...      4
# 2857  Weird behaviour with two Trac instances under ...      4
# 3205         defer processing during apache page render      4

# %%
train['Text']
# Out:
# 3958            WP_Insert_Post and GUID Issue [Wordpress]
# 2540                    How can I debug WordPress in IIS?
# 3594    wordpress: how to get x youtube thumbnails of ...
# 3240    Where to place a query to show only one post i...
# 3638                     Wordpress Blog RSS Feed Problems
# 3702                  Excluding one category in Wordpress
# 1720     debuging "register_activation_hook" in wordpress
# 3622                 Wordpress "Read more" is not working
# 3895                   Create blog post simply and easily
# 3727              Why is IE7 rendering these differently?
# 3900                   Using AJAX to load WordPress pages
# 3310                    WordPress Monthly Archive by Year
# 3521    Is there an easier way to add menu items to a ...
# 538     Wordpress: How can i move my index (blogpage) ...
# 3286    wp_list_categories does not show current category
# 388     What is the default URL for APEX for an Oracle...
# 2147      Oracle DB: How can I write query ignoring case?
# 1332    Oracle converts empty string to null but JPA d...
# 575     Is there a way to do full text search of all o...
# 1943    Faster 'select distinct thing_id,thing_name fr...
# 1564    When did oracle start supporting "top": select...
# 2063    Return an Oracle Ref Cursor to a SqlServer T-S...
# 2541    How do I insert sysdate into a column using OD...
# 981     Is it possible to kill a single query in oracl...
# 2282    Calculate difference between 2 date / times in...
# 404                                           Oracle date
# 2218    Compare strings by their written representatio...
# 1081    Allow Oracle User to connect from one IP addre...
# 2346    What's the equivalent of Oracle's to_char in A...
# 871     Oracle: how to use updateXML to update multipl...
# 338                   subversion diff including new files
# 663     Unlocking a SVN working copy which has unversi...
# 898                   Windows Backup for SVN Repositories
# 2376    Using svn:ignore to ignore everything but cert...
# 1323    How can I only commit property changes without...
# 2098    How to forbit subversion commits to svn:extern...
# 136                       How can I speed up SVN updates?
# 57                                           Begining SVN
# 1013         Is there any way to only update added files?
# 1137    Change Revesion Number in Subversion, even if ...
# 2027                               svn create tag problem
# 708     Is there some way to commit a file "partially"...
# 124                          Free Online SVN repositories
# 302     Create a tag upon every build of the application?
# 958                   Subversion plugin to Visual Studio?
# 3200    How to view error messages from ruby CGI app o...
# 2822                            PHP using too much memory
# 1831    Getting Apache to execute command on every pag...
# 2901      XAMPP: I edited PHP.ini, and now Apache crashes
# 195     Restrict Apache to only allow access using SSL...
# 3623    Adding slashes to the end of directories + mor...
# 689               IIS equivalent of VirtualHost in Apache
# 2272    Why do some page requests hang when fetching i...
# 1361                           Setting a header in apache
# 1874                     Apache Perl http headers problem
# 3444                         .htaccess mod-rewrite how to
# 2684        Problem with URL rewriting for same .php page
# 299     Top & httpd - demystifying what is actually ru...
# 2857    Weird behaviour with two Trac instances under ...
# 3205           defer processing during apache page render
# Name: Text, dtype: object

# %%
clf.fit(train['Text'], train['Label'])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(clf.predict(test['Text']), test['Label'])
# Out:
# 0.5032994923857868
